# %% [markdown]
# # <u>**Part 7**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Exercise 61**
#
# Using pandas load the following csv file into the DataFrame and assign to the df variable:
#
# * https://storage.googleapis.com/esmartdata-courses-files/dash-course/data.csv
#
# Set the index to the first column

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/dash-course/data.csv'

df = pd.read_csv(url, index_col=0)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# ### **Exercise 62**
#
# Extract list with column names of this DataFrame

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Name',
#  'Location',
#  'Year',
#  'Kilometers_Driven',
#  'Fuel_Type',
#  'Transmission',
#  'Owner_Type',
#  'Mileage',
#  'Engine',
#  'Power',
#  'Seats',
#  'New_Price',
#  'Price']

# %% [markdown]
# ### **Exercise 63**
#
# Remove the column 'New_Price' and print the first 5 rows to the console.

# %%
df.drop('New_Price', axis=1, inplace=True)
df.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# ### **Exercise 64**
#
# Find the number of missing values for each column.

# %%
df.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %% [markdown]
# ## **Exercise 65**
#
# Remove all rows with missing values in this object (use the inplace=True argument) In response, print info about df to the console.

# %%
df.dropna()
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 611.3+ KB

# %% [markdown]
# ### **Exercise 66**
#
# Replace all letters in column names with lowercase, e.g.
#
# * Name -> name
# * Fuel_Type -> fuel_type

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
df.columns = map(str.lower, df.columns)
df.head(5)
# Out:
#                                name    location  year  kilometers_driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   fuel_type transmission owner_type     mileage   engine      power  seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# ### **Exercise 67**
#
# Find the distribution of the owner_type column and print to the console.

# %%
df.value_counts('owner_type')
# Out:
# owner_type
# First             4929
# Second             968
# Third              113
# Fourth & Above       9
# dtype: int64

# %% [markdown]
# ### **Exercise 68**
#
# Look at the distribution of the engine column. Note that the type of this column is set to object. Remove the last three characters from each element in this column and convert this column to int type.
#
# In response, print the first five rows for two columns
#
# * name
# * engine

# %%
df[['name', 'engine']]
# Out:
#                                   name   engine
# 0               Maruti Wagon R LXI CNG   998 CC
# 1     Hyundai Creta 1.6 CRDi SX Option  1582 CC
# 2                         Honda Jazz V  1199 CC
# 3                    Maruti Ertiga VDI  1248 CC
# 4      Audi A4 New 2.0 TDI Multitronic  1968 CC
# ...                                ...      ...
# 6014                  Maruti Swift VDI  1248 CC
# 6015          Hyundai Xcent 1.1 CRDi S  1120 CC
# 6016             Mahindra Xylo D4 BSIV  2498 CC
# 6017                Maruti Wagon R VXI   998 CC
# 6018             Chevrolet Beat Diesel   936 CC
#
# [6019 rows x 2 columns]

# %%
df['engine'] = df['engine'].map(lambda x: int(x[:-3]))

# %% [markdown]
# ### **Exercise 69**
#
#
# Look at the distribution of the power column. Note that this column also has missing values as a 'null bhp'. Replace these values with np.nan. Use the np.where() function for this.
#
# In response, print the distribution of the power column to the console (only the top five most common values).

# %%
df['power'] = np.where(df['power'] == 'null bhp', np.nan, df['power'])
df['power'].value_counts()[:5]
# Out:
# 74 bhp      235
# 98.6 bhp    131
# 73.9 bhp    125
# 140 bhp     123
# 78.9 bhp    111
# Name: power, dtype: int64

# %% [markdown]
# ### **Exercise 70**
#
# Group this DataFrame by year and count the number of rows for each year.

# %%
df.groupby('year').size()
# Out:
# year
# 1998      4
# 1999      2
# 2000      4
# 2001      8
# 2002     15
# 2003     17
# 2004     31
# 2005     57
# 2006     78
# 2007    125
# 2008    174
# 2009    198
# 2010    342
# 2011    466
# 2012    580
# 2013    649
# 2014    797
# 2015    744
# 2016    741
# 2017    587
# 2018    298
# 2019    102
# dtype: int64
