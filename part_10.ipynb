# %% [markdown]
# # <u>**Part 10**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Exercise 91**
#
# Generate the *df_cat* dataframe again. Print basic statistics about this dataframe

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ml-course/insurance.csv'
df = pd.read_csv(url)
for col in list(df.select_dtypes(include=['object']).columns):
    df[col] = df[col].astype('category')
df_cat = df.select_dtypes(include=['category']).copy()
df_cat.head()
# Out:
#       sex smoker     region
# 0  female    yes  southwest
# 1    male     no  southeast
# 2    male     no  southeast
# 3    male     no  northwest
# 4    male     no  northwest

# %%
df_cat.describe()
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %% [markdown]
# ### **Exercise 92**
#
# Generate the *df_num* dataframe again. Print basic statistics about this dataframe

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ml-course/insurance.csv'
df = pd.read_csv(url)
for col in list(df.select_dtypes(include=['object']).columns):
    df[col] = df[col].astype('category')
df_num = df.select_dtypes(include=['float', 'int']).copy()

df_num.head()
# Out:
#    age     bmi  children      charges
# 0   19  27.900         0  16884.92400
# 1   18  33.770         1   1725.55230
# 2   28  33.000         3   4449.46200
# 3   33  22.705         0  21984.47061
# 4   32  28.880         0   3866.85520

# %%
df_num.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ### **Exercise 93**
#
# Calculate basic statistics of *df* dataframe only for numeric variables, transpose the result and extract two columns:
#
# * mean
# * std

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.describe().T[['mean', 'std']]
# Out:
#                   mean           std
# age          39.207025     14.049960
# bmi          30.663397      6.098187
# children      1.094918      1.205493
# charges   13270.422265  12110.011237

# %% [markdown]
# ### **Exercise 94**
#
# Check for missing values in this DataFrame

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ### **Exercise 95**
#
# Convert all categorical variable to 0-1 encoding and assign it to the df_dummies variable. Show the first five rows

# %%
df_dummies = pd.get_dummies(df, drop_first=True)
df_dummies.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %% [markdown]
# ### **Exercise 96**
#
# Calculate the correlations of columns in the df_dummies and assign it to the corr variable.

# %%
corr = df_dummies.corr()
corr
# Out:
#                        age       bmi  children   charges  sex_male  \
# age               1.000000  0.109272  0.042469  0.299008 -0.020856
# bmi               0.109272  1.000000  0.012759  0.198341  0.046371
# children          0.042469  0.012759  1.000000  0.067998  0.017163
# charges           0.299008  0.198341  0.067998  1.000000  0.057292
# sex_male         -0.020856  0.046371  0.017163  0.057292  1.000000
# smoker_yes       -0.025019  0.003750  0.007673  0.787251  0.076185
# region_northwest -0.000407 -0.135996  0.024806 -0.039905 -0.011156
# region_southeast -0.011642  0.270025 -0.023066  0.073982  0.017117
# region_southwest  0.010016 -0.006205  0.021914 -0.043210 -0.004184
#
#                   smoker_yes  region_northwest  region_southeast  \
# age                -0.025019         -0.000407         -0.011642
# bmi                 0.003750         -0.135996          0.270025
# children            0.007673          0.024806         -0.023066
# ...

# %% [markdown]
# ### **Exercise 97**
#
# Extract the charges colum from the corr dataframe and sort the values in ascending order

# %%
corr['charges'].sort_values(ascending=False)
# Out:
# charges             1.000000
# smoker_yes          0.787251
# age                 0.299008
# bmi                 0.198341
# region_southeast    0.073982
# children            0.067998
# sex_male            0.057292
# region_northwest   -0.039905
# region_southwest   -0.043210
# Name: charges, dtype: float64

# %% [markdown]
# ### **Exercise 98**
#
# Make a copy of the df_dummies and assign to data variable. Then pop the charges column from this object and assign it to the target variable.

# %%
data = df_dummies.copy()
data.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
target = data.pop('charges')
target.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %% [markdown]
# ### **Exercise 99**
#
# Create the DataFrame from the following dictionary and assign it to the df variable:
#
# data = {
#     'size': ['XL', 'L', 'M', 'L', 'M'], <br>
#     'color': ['red', 'green', 'blue', 'green', 'red'], <br>
#     'gender': ['female', 'male', 'male', 'female', 'female'], <br>
#     'price': [199.0, 89.0, 99.0, 129.0, 79.0], <br>
#     'weight': [500, 450, 300, 380, 410], <br>
#     'bought': ['yes', 'no', 'yes', 'no', 'yes'] <br>
# }

# %%
data = {
    'size': ['XL', 'L', 'M', 'L', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red'],
    'gender': ['female', 'male', 'male', 'female', 'female'],
    'price': [199.0, 89.0, 99.0, 129.0, 79.0],
    'weight': [500, 450, 300, 380, 410],
    'bought': ['yes', 'no', 'yes', 'no', 'yes']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %% [markdown]
# ### **Exercise 100**
#
# Convert the following columns
#
# * size -> category
# * color -> category
# * gender -> category
# * weight -> float
# * bought -> category

# %%
df = pd.DataFrame(data)
for col in ['size', 'color', 'gender', 'bought']:
    df[col] = df[col].astype('category')
 
df['weight'] = df['weight'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      category
#  1   color   5 non-null      category
#  2   gender  5 non-null      category
#  3   price   5 non-null      float64
#  4   weight  5 non-null      float64
#  5   bought  5 non-null      category
# dtypes: category(4), float64(2)
# memory usage: 740.0 bytes
